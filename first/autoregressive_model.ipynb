# %%
import tensorflow as tf 
tf.__version__
# Out:
# '2.8.0'

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, Adam

import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
series = np.sin(0.1 * np.arange(200)) # + np.random.randn(200) * 0.1

# %%
plt.plot(series)
# plt.show()

# %% [markdown]
# ### Build a dataset

# %%
T = 10
X = []
Y = []

# %%
for t in range(len(series) - T):
    x = series[t : t+T]
    X.append(x)
    y = series[t+T]
    Y.append(y)

# %%
X = np.array(X).reshape(-1 ,T)
Y = np.array(Y)
N = len(X)
print(f"X.shape:{X.shape}, Y.shape:{Y.shape}, N.length:{N}")
# Out:
# X.shape:(190, 10), Y.shape:(190,), N.length:190

# %%
# linear model
i = Input(shape=(T, ))
x = Dense(1)(i)

model = Model(i, x)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 10)]              0
#
#  dense (Dense)               (None, 1)                 11
#
# =================================================================
# Total params: 11
# Trainable params: 11
# Non-trainable params: 0
# _________________________________________________________________
# 2022-03-14 15:15:25.504706: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.compile(loss='mse', optimizer=Adam(lr=0.1))
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
# train the model
# X:학습데이터, Y:정답데이터, epochs=80, validation_data:검증 데이터 
r = model.fit(X[:-N//2], Y[:-N//2], epochs=80, validation_data=(X[-N//2:], Y[-N//2:]))
# Out:
# Epoch 1/80
# 3/3 [==============================] - 0s 55ms/step - loss: 1.8492 - val_loss: 0.1072
# Epoch 2/80
# 3/3 [==============================] - 0s 10ms/step - loss: 0.4633 - val_loss: 0.7505
# Epoch 3/80
# 3/3 [==============================] - 0s 11ms/step - loss: 0.8362 - val_loss: 0.3250
# Epoch 4/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1761 - val_loss: 0.0495
# Epoch 5/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1994 - val_loss: 0.2610
# Epoch 6/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3340 - val_loss: 0.1154
# Epoch 7/80
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0897 - val_loss: 0.0271
# Epoch 8/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0567 - val_loss: 0.1407
# Epoch 9/80
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1342 - val_loss: 0.0633
# Epoch 10/80
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0404 - val_loss: 0.0082
# Epoch 11/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0228 - val_loss: 0.0727
# Epoch 12/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0585 - val_loss: 0.0408
# Epoch 13/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0175 - val_loss: 0.0047
# Epoch 14/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0129 - val_loss: 0.0207
# Epoch 15/80
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0217 - val_loss: 0.0070
# Epoch 16/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0038 - val_loss: 0.0027
# Epoch 17/80
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0083 - val_loss: 0.0074
# Epoch 18/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0077 - val_loss: 5.2789e-04
# Epoch 19/80
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0010 - val_loss: 0.0041
# Epoch 20/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0050 - val_loss: 0.0027
# Epoch 21/80
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0015 - val_loss: 4.7119e-04
# Epoch 22/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0014 - val_loss: 0.0031
# Epoch 23/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0021 - val_loss: 5.9958e-04
# Epoch 24/80
# 3/3 [==============================] - 0s 13ms/step - loss: 2.9928e-04 - val_loss: 6.0249e-04
# Epoch 25/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0010 - val_loss: 7.2591e-04
# Epoch 26/80
# 3/3 [==============================] - 0s 12ms/step - loss: 3.5715e-04 - val_loss: 8.1117e-05
# Epoch 27/80
# 3/3 [==============================] - 0s 12ms/step - loss: 3.6659e-04 - val_loss: 3.7163e-04
# Epoch 28/80
# 3/3 [==============================] - 0s 12ms/step - loss: 3.7739e-04 - val_loss: 2.1745e-05
# Epoch 29/80
# 3/3 [==============================] - 0s 11ms/step - loss: 8.6780e-05 - val_loss: 2.3844e-04
# Epoch 30/80
# 3/3 [==============================] - 0s 14ms/step - loss: 2.2921e-04 - val_loss: 4.6895e-05
# Epoch 31/80
# 3/3 [==============================] - 0s 12ms/step - loss: 3.6283e-05 - val_loss: 1.3173e-04
# Epoch 32/80
# 3/3 [==============================] - 0s 11ms/step - loss: 1.2082e-04 - val_loss: 1.1888e-04
# Epoch 33/80
# 3/3 [==============================] - 0s 12ms/step - loss: 4.5355e-05 - val_loss: 1.3476e-05
# Epoch 34/80
# 3/3 [==============================] - 0s 13ms/step - loss: 4.0270e-05 - val_loss: 4.9911e-05
# Epoch 35/80
# 3/3 [==============================] - 0s 12ms/step - loss: 3.0260e-05 - val_loss: 4.1614e-06
# Epoch 36/80
# 3/3 [==============================] - 0s 14ms/step - loss: 1.6706e-05 - val_loss: 2.1282e-05
# Epoch 37/80
# 3/3 [==============================] - 0s 13ms/step - loss: 2.3500e-05 - val_loss: 1.5494e-06
# Epoch 38/80
# 3/3 [==============================] - 0s 11ms/step - loss: 5.8895e-06 - val_loss: 1.3617e-05
# Epoch 39/80
# 3/3 [==============================] - 0s 12ms/step - loss: 1.3369e-05 - val_loss: 1.5433e-06
# Epoch 40/80
# 3/3 [==============================] - 0s 13ms/step - loss: 3.5314e-06 - val_loss: 1.0248e-05
# Epoch 41/80
# 3/3 [==============================] - 0s 12ms/step - loss: 7.9576e-06 - val_loss: 2.3788e-06
# Epoch 42/80
# 3/3 [==============================] - 0s 11ms/step - loss: 1.0598e-06 - val_loss: 3.1023e-06
# Epoch 43/80
# 3/3 [==============================] - 0s 13ms/step - loss: 3.7772e-06 - val_loss: 2.5069e-06
# Epoch 44/80
# 3/3 [==============================] - 0s 12ms/step - loss: 1.0269e-06 - val_loss: 1.2225e-06
# Epoch 45/80
# 3/3 [==============================] - 0s 10ms/step - loss: 2.4758e-06 - val_loss: 8.2282e-07
# Epoch 46/80
# 3/3 [==============================] - 0s 14ms/step - loss: 4.6417e-07 - val_loss: 5.3752e-07
# Epoch 47/80
# 3/3 [==============================] - 0s 12ms/step - loss: 1.1155e-06 - val_loss: 5.2521e-07
# Epoch 48/80
# 3/3 [==============================] - 0s 11ms/step - loss: 3.8539e-07 - val_loss: 5.5522e-07
# Epoch 49/80
# 3/3 [==============================] - 0s 12ms/step - loss: 5.7798e-07 - val_loss: 4.7335e-07
# Epoch 50/80
# 3/3 [==============================] - 0s 10ms/step - loss: 1.8379e-07 - val_loss: 1.5431e-07
# Epoch 51/80
# 3/3 [==============================] - 0s 13ms/step - loss: 2.9226e-07 - val_loss: 2.7348e-07
# Epoch 52/80
# 3/3 [==============================] - 0s 13ms/step - loss: 1.1178e-07 - val_loss: 6.0005e-08
# Epoch 53/80
# 3/3 [==============================] - 0s 12ms/step - loss: 1.5591e-07 - val_loss: 9.1844e-08
# Epoch 54/80
# 3/3 [==============================] - 0s 12ms/step - loss: 5.3308e-08 - val_loss: 4.5068e-08
# Epoch 55/80
# 3/3 [==============================] - 0s 13ms/step - loss: 8.9505e-08 - val_loss: 4.5164e-08
# Epoch 56/80
# 3/3 [==============================] - 0s 10ms/step - loss: 3.4044e-08 - val_loss: 4.1861e-08
# Epoch 57/80
# 3/3 [==============================] - 0s 11ms/step - loss: 5.1520e-08 - val_loss: 2.7372e-08
# Epoch 58/80
# 3/3 [==============================] - 0s 9ms/step - loss: 1.1350e-08 - val_loss: 2.0322e-08
# Epoch 59/80
# 3/3 [==============================] - 0s 12ms/step - loss: 2.5752e-08 - val_loss: 1.4879e-08
# Epoch 60/80
# 3/3 [==============================] - 0s 10ms/step - loss: 7.0101e-09 - val_loss: 1.0135e-08
# Epoch 61/80
# 3/3 [==============================] - 0s 10ms/step - loss: 1.5160e-08 - val_loss: 4.5218e-09
# Epoch 62/80
# 3/3 [==============================] - 0s 11ms/step - loss: 3.0757e-09 - val_loss: 5.8607e-09
# Epoch 63/80
# 3/3 [==============================] - 0s 11ms/step - loss: 7.2201e-09 - val_loss: 1.0182e-09
# Epoch 64/80
# 3/3 [==============================] - 0s 10ms/step - loss: 1.3680e-09 - val_loss: 4.3536e-09
# Epoch 65/80
# 3/3 [==============================] - 0s 10ms/step - loss: 3.2897e-09 - val_loss: 8.2776e-11
# Epoch 66/80
# 3/3 [==============================] - 0s 10ms/step - loss: 8.6350e-10 - val_loss: 3.1000e-09
# Epoch 67/80
# 3/3 [==============================] - 0s 11ms/step - loss: 1.8488e-09 - val_loss: 2.1579e-10
# Epoch 68/80
# 3/3 [==============================] - 0s 10ms/step - loss: 8.4381e-10 - val_loss: 1.1971e-09
# Epoch 69/80
# 3/3 [==============================] - 0s 11ms/step - loss: 7.9458e-10 - val_loss: 1.8205e-10
# Epoch 70/80
# 3/3 [==============================] - 0s 12ms/step - loss: 5.7265e-10 - val_loss: 3.9171e-10
# Epoch 71/80
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6543e-10 - val_loss: 2.8887e-10
# Epoch 72/80
# 3/3 [==============================] - 0s 11ms/step - loss: 3.8919e-10 - val_loss: 1.3503e-10
# Epoch 73/80
# 3/3 [==============================] - 0s 11ms/step - loss: 7.3173e-11 - val_loss: 2.0836e-10
# Epoch 74/80
# 3/3 [==============================] - 0s 10ms/step - loss: 2.1748e-10 - val_loss: 4.7362e-11
# Epoch 75/80
# 3/3 [==============================] - 0s 10ms/step - loss: 6.4026e-11 - val_loss: 1.4363e-10
# Epoch 76/80
# 3/3 [==============================] - 0s 10ms/step - loss: 1.0593e-10 - val_loss: 6.6466e-12
# Epoch 77/80
# 3/3 [==============================] - 0s 11ms/step - loss: 4.2745e-11 - val_loss: 4.8472e-11
# Epoch 78/80
# 3/3 [==============================] - 0s 11ms/step - loss: 3.1907e-11 - val_loss: 1.4078e-11
# Epoch 79/80
# 3/3 [==============================] - 0s 9ms/step - loss: 3.6886e-11 - val_loss: 1.9454e-11
# Epoch 80/80
# 3/3 [==============================] - 0s 11ms/step - loss: 1.2972e-11 - val_loss: 2.8948e-11

# %%
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %% [markdown]
# ### "Wrong" forecast usring true targets

# %%
validation_target = Y[-N//2:]
validation_predictions = []

i = -N//2 
while len(validation_predictions) < len(validation_target):
    p = model.predict(X[i].reshape(1, -1))[0,0] # 1x1 array -> scalar
    i += 1
    
    validation_predictions.append(p)

# %%
plt.plot(validation_target, label='forecast_target')
plt.plot(validation_predictions, label='forecast_prediction')
plt.legend()

# %%
validation_target = Y[-N//2:]
validation_predictions = []

# last train input 
last_x = X[-N//2]

# %%
print(len(validation_target))
print(last_x)
# Out:
# 95
# [-0.07515112 -0.17432678 -0.27176063 -0.36647913 -0.45753589 -0.54402111
#  -0.62507065 -0.69987469 -0.76768581 -0.82782647]

# %%
print(last_x.reshape(1, -1))
# Out:
# [[-0.07515112 -0.17432678 -0.27176063 -0.36647913 -0.45753589 -0.54402111
#   -0.62507065 -0.69987469 -0.76768581 -0.82782647]]

# %%
print(model.predict(last_x.reshape(1, -1))[0,0])
# Out:
# -0.8796975

# %%
while len(validation_predictions) < len(validation_target):
    p = model.predict(last_x.reshape(1, -1))[0,0] # 1x1 array -> scalar
    validation_predictions.append(p)
    
    last_x = np.roll(last_x, -1)
    last_x[-1] = p

# %%
plt.plot(validation_target, label='forecast_target')
plt.plot(validation_predictions, label='forecast_prediction')
plt.legend()

# %% [markdown]
# ### Noise examples

# %%
series = np.sin(0.1 * np.arange(200)) + np.random.randn(200) * 0.1

plt.plot(series)
plt.show()

# %%
T = 10
X = []
Y = []
for t in range(len(series) - T):
    x = series[t : t+T]
    X.append(x)
    y = series[t+T]
    Y.append(y)

# %%
X = np.array(X).reshape(-1 ,T)
Y = np.array(Y)
N = len(X)
print(f"X.shape:{X.shape}, Y.shape:{Y.shape}, N.length:{N}")
# Out:
# X.shape:(190, 10), Y.shape:(190,), N.length:190

# %%
i = Input(shape=(T,))
x = Dense(1)(i)
model = Model(i, x)
model.compile(loss='mse', optimizer=Adam(lr=0.1))
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
r = model.fit(X[:-N//2], Y[:-N//2], epochs=80, validation_data=(X[-N//2:], Y[-N//2:]))
# Out:
# Epoch 1/80
# 3/3 [==============================] - 0s 40ms/step - loss: 0.9466 - val_loss: 0.2226
# Epoch 2/80
# 3/3 [==============================] - 0s 10ms/step - loss: 0.5576 - val_loss: 0.5346
# Epoch 3/80
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3236 - val_loss: 0.0854
# Epoch 4/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1331 - val_loss: 0.2248
# Epoch 5/80
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2868 - val_loss: 0.1084
# Epoch 6/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0789 - val_loss: 0.0942
# Epoch 7/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0974 - val_loss: 0.1472
# Epoch 8/80
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1025 - val_loss: 0.0499
# Epoch 9/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0377 - val_loss: 0.1033
# Epoch 10/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0735 - val_loss: 0.0884
# Epoch 11/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0419 - val_loss: 0.0467
# Epoch 12/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0357 - val_loss: 0.0611
# Epoch 13/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0382 - val_loss: 0.0426
# Epoch 14/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0256 - val_loss: 0.0432
# Epoch 15/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0297 - val_loss: 0.0399
# Epoch 16/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0225 - val_loss: 0.0411
# Epoch 17/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0251 - val_loss: 0.0405
# Epoch 18/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0230 - val_loss: 0.0375
# Epoch 19/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0222 - val_loss: 0.0383
# Epoch 20/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0215 - val_loss: 0.0361
# Epoch 21/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0201 - val_loss: 0.0369
# Epoch 22/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0208 - val_loss: 0.0357
# Epoch 23/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0205 - val_loss: 0.0354
# Epoch 24/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0200 - val_loss: 0.0346
# Epoch 25/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0196 - val_loss: 0.0351
# Epoch 26/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0193 - val_loss: 0.0341
# Epoch 27/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0196 - val_loss: 0.0342
# Epoch 28/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0189 - val_loss: 0.0333
# Epoch 29/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0186 - val_loss: 0.0336
# Epoch 30/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0185 - val_loss: 0.0324
# Epoch 31/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0178 - val_loss: 0.0320
# Epoch 32/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0180 - val_loss: 0.0319
# Epoch 33/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0175 - val_loss: 0.0312
# Epoch 34/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0173 - val_loss: 0.0310
# Epoch 35/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0172 - val_loss: 0.0305
# Epoch 36/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0168 - val_loss: 0.0306
# Epoch 37/80
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0167 - val_loss: 0.0298
# Epoch 38/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0166 - val_loss: 0.0296
# Epoch 39/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0164 - val_loss: 0.0293
# Epoch 40/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0164 - val_loss: 0.0296
# Epoch 41/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0162 - val_loss: 0.0286
# Epoch 42/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0158 - val_loss: 0.0282
# Epoch 43/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0169 - val_loss: 0.0284
# Epoch 44/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0159 - val_loss: 0.0280
# Epoch 45/80
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0157 - val_loss: 0.0273
# Epoch 46/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0151 - val_loss: 0.0271
# Epoch 47/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0148 - val_loss: 0.0267
# Epoch 48/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0147 - val_loss: 0.0265
# Epoch 49/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0148 - val_loss: 0.0265
# Epoch 50/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0143 - val_loss: 0.0260
# Epoch 51/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0145 - val_loss: 0.0258
# Epoch 52/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0140 - val_loss: 0.0257
# Epoch 53/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0142 - val_loss: 0.0253
# Epoch 54/80
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0145 - val_loss: 0.0249
# Epoch 55/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0137 - val_loss: 0.0251
# Epoch 56/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0138 - val_loss: 0.0245
# Epoch 57/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0134 - val_loss: 0.0243
# Epoch 58/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0134 - val_loss: 0.0242
# Epoch 59/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0136 - val_loss: 0.0240
# Epoch 60/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0132 - val_loss: 0.0237
# Epoch 61/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0131 - val_loss: 0.0236
# Epoch 62/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0129 - val_loss: 0.0233
# Epoch 63/80
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0128 - val_loss: 0.0231
# Epoch 64/80
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0127 - val_loss: 0.0231
# Epoch 65/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0129 - val_loss: 0.0230
# Epoch 66/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0123 - val_loss: 0.0227
# Epoch 67/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0126 - val_loss: 0.0225
# Epoch 68/80
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0125 - val_loss: 0.0223
# Epoch 69/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0122 - val_loss: 0.0222
# Epoch 70/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0124 - val_loss: 0.0221
# Epoch 71/80
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0125 - val_loss: 0.0220
# Epoch 72/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0119 - val_loss: 0.0220
# Epoch 73/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0124 - val_loss: 0.0218
# Epoch 74/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0117 - val_loss: 0.0219
# Epoch 75/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0127 - val_loss: 0.0214
# Epoch 76/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0121 - val_loss: 0.0217
# Epoch 77/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0127 - val_loss: 0.0215
# Epoch 78/80
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0117 - val_loss: 0.0214
# Epoch 79/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0120 - val_loss: 0.0210
# Epoch 80/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0124 - val_loss: 0.0211

# %%
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
validation_target = Y[-N//2:]
validation_predictions = []
i = -N//2

while len(validation_predictions) < len(validation_target):
    p = model.predict(X[i].reshape(1, -1))[0,0]
    i += 1
    
    validation_predictions.append(p)

# %%
plt.plot(validation_target, label='forecast_target')
plt.plot(validation_predictions, label='forecast_predictions')
plt.legend()

# %%
validation_target = Y[-N//2:]
validation_predictions = []

last_x = X[-N//2]
while len(validation_predictions) < len(validation_target):
    p = model.predict(last_x.reshape(1, -1))[0,0] # 1x1 array -> scalar
    validation_predictions.append(p)
    
    last_x = np.roll(last_x, -1)
    last_x[-1] = p

# %%
plt.plot(validation_target, label='forecast_target')
plt.plot(validation_predictions, label='forecast_predictions')
plt.legend()

# %%
print(last_x)
# Out:
# [0.50496787 0.55877024 0.60530794 0.64383912 0.67398578 0.69558507
#  0.70820141 0.71175647 0.7063024  0.69186425]
