# %%
from tensorflow.keras.layers import Input, SimpleRNN, Dense, Flatten, LSTM
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, Adam

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
series = np.sin(0.1 * np.arange(200)) # + np.random.randn(200) * 0.1 
plt.plot(series)
plt.show()

# %%
series = np.sin(0.1 * np.arange(200)) + np.random.randn(200) * 0.1 
plt.plot(series)
plt.show()

# %%
# build the dataset
T = 10
X = []
Y = []
for t in range(len(series) - T):
    x = series[t:t+T]
    X.append(x)
    y = series[t+T]
    Y.append(y)

np.array(X).shape
# np.array(Y).shape
# Out:
# (190, 10)

# %%
# sequences data -> N x T x D -> 190 x 10 x 1
X = np.array(X).reshape(-1, T, 1)
Y = np.array(Y)
N = len(X)
print(f"X.shape:{X.shape}, Y.shape:{Y.shape}, N.length:{N}")
# Out:
# X.shape:(190, 10, 1), Y.shape:(190,), N.length:190

# %%
# build a RNN model 
# 1. Input  
i = Input(shape=(T, 1)) # T x D
# 2. SimpleRNN(5, activation='tanh')
#x = SimpleRNN(5)(i)
x = LSTM(5)(i)
# 3. Output 
x = Dense(1)(x)
model = Model(i , x)
model.compile(loss='mse', optimizer=Adam(lr=0.1))
# Quiz. trainable params -> 41 = hidden weights + current weights + bais 
#                              = (features * unit) + (unit * unit) + (feature * unit)
#                              = (1 * 5) + (5 * 5) + (1 * 5) = 35
# Out:
# 2022-03-16 11:32:01.904604: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /opt/anaconda3/lib/python3.8/site-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 10, 1)]           0
#
#  lstm (LSTM)                 (None, 5)                 140
#
#  dense (Dense)               (None, 1)                 6
#
# =================================================================
# Total params: 146
# Trainable params: 146
# Non-trainable params: 0
# _________________________________________________________________

# %%
# train the RNN
r = model.fit(X[:-N//2], Y[:-N//2], epochs=80, validation_data=(X[-N//2:], Y[-N//2:]))
# Out:
# Epoch 1/80
# 3/3 [==============================] - 3s 227ms/step - loss: 0.5671 - val_loss: 0.2119
# Epoch 2/80
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1453 - val_loss: 0.1635
# Epoch 3/80
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0741 - val_loss: 0.0799
# Epoch 4/80
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0615 - val_loss: 0.0626
# Epoch 5/80
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0402 - val_loss: 0.0414
# Epoch 6/80
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0354 - val_loss: 0.0506
# Epoch 7/80
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0312 - val_loss: 0.0272
# Epoch 8/80
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0266 - val_loss: 0.0313
# Epoch 9/80
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0286 - val_loss: 0.0279
# Epoch 10/80
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0271 - val_loss: 0.0296
# Epoch 11/80
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0276 - val_loss: 0.0252
# Epoch 12/80
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0235 - val_loss: 0.0265
# Epoch 13/80
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0261 - val_loss: 0.0240
# Epoch 14/80
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0242 - val_loss: 0.0249
# Epoch 15/80
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0230 - val_loss: 0.0269
# Epoch 16/80
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0249 - val_loss: 0.0235
# Epoch 17/80
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0227 - val_loss: 0.0240
# Epoch 18/80
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0232 - val_loss: 0.0244
# Epoch 19/80
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0222 - val_loss: 0.0230
# Epoch 20/80
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0219 - val_loss: 0.0232
# Epoch 21/80
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0211 - val_loss: 0.0221
# Epoch 22/80
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0208 - val_loss: 0.0219
# Epoch 23/80
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0203 - val_loss: 0.0216
# Epoch 24/80
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0239 - val_loss: 0.0216
# Epoch 25/80
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0232 - val_loss: 0.0225
# Epoch 26/80
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0206 - val_loss: 0.0238
# Epoch 27/80
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0196 - val_loss: 0.0245
# Epoch 28/80
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0215 - val_loss: 0.0209
# Epoch 29/80
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0209 - val_loss: 0.0202
# Epoch 30/80
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0211 - val_loss: 0.0214
# Epoch 31/80
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0224 - val_loss: 0.0203
# Epoch 32/80
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0213 - val_loss: 0.0230
# Epoch 33/80
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0174 - val_loss: 0.0215
# Epoch 34/80
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0195 - val_loss: 0.0198
# Epoch 35/80
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0190 - val_loss: 0.0190
# Epoch 36/80
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0174 - val_loss: 0.0186
# Epoch 37/80
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0157 - val_loss: 0.0203
# Epoch 38/80
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0165 - val_loss: 0.0183
# Epoch 39/80
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0170 - val_loss: 0.0184
# Epoch 40/80
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0173 - val_loss: 0.0181
# Epoch 41/80
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0164 - val_loss: 0.0176
# Epoch 42/80
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0155 - val_loss: 0.0176
# Epoch 43/80
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0150 - val_loss: 0.0175
# Epoch 44/80
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0148 - val_loss: 0.0185
# Epoch 45/80
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0148 - val_loss: 0.0173
# Epoch 46/80
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0148 - val_loss: 0.0191
# Epoch 47/80
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0151 - val_loss: 0.0181
# Epoch 48/80
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0145 - val_loss: 0.0178
# Epoch 49/80
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0154 - val_loss: 0.0176
# Epoch 50/80
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0160 - val_loss: 0.0171
# Epoch 51/80
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0184 - val_loss: 0.0177
# Epoch 52/80
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0157 - val_loss: 0.0195
# Epoch 53/80
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0165 - val_loss: 0.0190
# Epoch 54/80
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0176 - val_loss: 0.0188
# Epoch 55/80
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0173 - val_loss: 0.0194
# Epoch 56/80
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0144 - val_loss: 0.0232
# Epoch 57/80
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0147 - val_loss: 0.0238
# Epoch 58/80
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0171 - val_loss: 0.0181
# Epoch 59/80
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0150 - val_loss: 0.0210
# Epoch 60/80
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0151 - val_loss: 0.0268
# Epoch 61/80
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0176 - val_loss: 0.0178
# Epoch 62/80
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0150 - val_loss: 0.0219
# Epoch 63/80
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0152 - val_loss: 0.0207
# Epoch 64/80
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0193 - val_loss: 0.0191
# Epoch 65/80
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0162 - val_loss: 0.0213
# Epoch 66/80
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0178 - val_loss: 0.0190
# Epoch 67/80
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0166 - val_loss: 0.0206
# Epoch 68/80
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0137 - val_loss: 0.0197
# Epoch 69/80
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0149 - val_loss: 0.0182
# Epoch 70/80
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0163 - val_loss: 0.0187
# Epoch 71/80
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0189 - val_loss: 0.0206
# Epoch 72/80
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0162 - val_loss: 0.0212
# Epoch 73/80
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0143 - val_loss: 0.0194
# Epoch 74/80
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0166 - val_loss: 0.0183
# Epoch 75/80
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0147 - val_loss: 0.0175
# Epoch 76/80
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0150 - val_loss: 0.0183
# Epoch 77/80
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0126 - val_loss: 0.0183
# Epoch 78/80
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0148 - val_loss: 0.0176
# Epoch 79/80
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0151 - val_loss: 0.0183
# Epoch 80/80
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0153 - val_loss: 0.0183

# %%
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
# Wrong forecast using true targets
validation_target = Y[-N//2:]
validation_predictions = []

i = -N//2 

while len(validation_predictions) < len(validation_target):
    p = model.predict(X[i].reshape(1, -1, 1))[0,0]
    i += 1
    
    validation_predictions.append(p)

# %%
plt.plot(validation_target, label='validation_target')
plt.plot(validation_predictions, label='validation_predictions')
plt.legend()

# %%
# Forecast future values
validation_target = Y[-N//2:]
validation_predictions = []

# last train input
last_x = X[-N//2]  

while len(validation_predictions) < len(validation_target):
    p = model.predict(last_x.reshape(1, -1, 1))[0,0]
    
    validation_predictions.append(p)
    
    last_x = np.roll(last_x, -1)
#     print(last_x)
    last_x[-1] = p

# %%
plt.plot(validation_target, label='validation_target')
plt.plot(validation_predictions, label='validation_predictions')
plt.legend()
