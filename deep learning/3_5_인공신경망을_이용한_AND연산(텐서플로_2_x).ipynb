# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.7.0'

# %%
import numpy as np

# %%
X = np.array([
               [0 , 0],
               [0 , 1],
               [1 , 0],
               [1 , 1]
    ])

# %%
X
# Out:
# array([[0, 0],
#        [0, 1],
#        [1, 0],
#        [1, 1]])

# %%
y = np.array([
               [0],
               [0],
               [0],
               [1]
])

# %%
y
# Out:
# array([[0],
#        [0],
#        [0],
#        [1]])

# %%
from tensorflow.keras.models import Sequential

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
model = Sequential()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from tensorflow.keras.layers import Dense

# %%
model.add(Dense(1, input_dim=2, activation="sigmoid"))

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
model.layers[0].get_weights()
# Out:
# [array([[1.0046355],
#         [0.7959553]], dtype=float32), array([0.], dtype=float32)]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 3
#
# =================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from tensorflow.keras.optimizers import Adam

# %%
model.compile(
               loss="binary_crossentropy", 
               optimizer=Adam(lr=0.1),
               metrics = ["acc"]
              )
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
model.fit(X, y , epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.8328 - acc: 0.5000
# Epoch 2/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.7637 - acc: 0.5000
# Epoch 3/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.7034 - acc: 0.5000
# Epoch 4/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6526 - acc: 0.5000
# Epoch 5/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6122 - acc: 0.5000
# Epoch 6/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5822 - acc: 0.7500
# Epoch 7/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5617 - acc: 1.0000
# Epoch 8/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5491 - acc: 0.7500
# Epoch 9/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5417 - acc: 0.7500
# Epoch 10/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.5371 - acc: 0.7500
# Epoch 11/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5330 - acc: 0.7500
# Epoch 12/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5280 - acc: 0.7500
# Epoch 13/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5213 - acc: 0.7500
# Epoch 14/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5130 - acc: 0.7500
# Epoch 15/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5030 - acc: 0.7500
# Epoch 16/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4917 - acc: 0.7500
# Epoch 17/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4795 - acc: 0.7500
# Epoch 18/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4667 - acc: 0.7500
# Epoch 19/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4539 - acc: 0.7500
# Epoch 20/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.4412 - acc: 0.7500
# Epoch 21/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4291 - acc: 0.7500
# Epoch 22/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.4176 - acc: 0.7500
# Epoch 23/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4071 - acc: 0.7500
# Epoch 24/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.3974 - acc: 1.0000
# Epoch 25/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3886 - acc: 1.0000
# Epoch 26/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3806 - acc: 1.0000
# Epoch 27/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3731 - acc: 1.0000
# Epoch 28/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.3662 - acc: 1.0000
# Epoch 29/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.3596 - acc: 1.0000
# Epoch 30/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3531 - acc: 1.0000
# Epoch 31/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.3467 - acc: 1.0000
# Epoch 32/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.3403 - acc: 1.0000
# Epoch 33/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3339 - acc: 1.0000
# Epoch 34/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3275 - acc: 1.0000
# Epoch 35/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3210 - acc: 1.0000
# Epoch 36/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3147 - acc: 1.0000
# Epoch 37/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3085 - acc: 1.0000
# Epoch 38/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.3024 - acc: 1.0000
# Epoch 39/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2966 - acc: 1.0000
# Epoch 40/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2910 - acc: 1.0000
# Epoch 41/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2857 - acc: 1.0000
# Epoch 42/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2807 - acc: 1.0000
# Epoch 43/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.2759 - acc: 1.0000
# Epoch 44/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.2713 - acc: 1.0000
# Epoch 45/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2669 - acc: 1.0000
# Epoch 46/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2626 - acc: 1.0000
# Epoch 47/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2584 - acc: 1.0000
# Epoch 48/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2544 - acc: 1.0000
# Epoch 49/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.2504 - acc: 1.0000
# Epoch 50/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.2465 - acc: 1.0000
# Epoch 51/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.2426 - acc: 1.0000
# Epoch 52/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2388 - acc: 1.0000
# Epoch 53/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2351 - acc: 1.0000
# Epoch 54/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2315 - acc: 1.0000
# Epoch 55/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2280 - acc: 1.0000
# Epoch 56/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2246 - acc: 1.0000
# Epoch 57/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.2213 - acc: 1.0000
# Epoch 58/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2181 - acc: 1.0000
# Epoch 59/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2150 - acc: 1.0000
# Epoch 60/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2120 - acc: 1.0000
# Epoch 61/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2090 - acc: 1.0000
# Epoch 62/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.2062 - acc: 1.0000
# Epoch 63/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.2034 - acc: 1.0000
# Epoch 64/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.2006 - acc: 1.0000
# Epoch 65/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1980 - acc: 1.0000
# Epoch 66/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1953 - acc: 1.0000
# Epoch 67/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1928 - acc: 1.0000
# Epoch 68/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1902 - acc: 1.0000
# Epoch 69/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1878 - acc: 1.0000
# Epoch 70/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.1854 - acc: 1.0000
# Epoch 71/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1830 - acc: 1.0000
# Epoch 72/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1807 - acc: 1.0000
# Epoch 73/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.1784 - acc: 1.0000
# Epoch 74/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1762 - acc: 1.0000
# Epoch 75/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.1740 - acc: 1.0000
# Epoch 76/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1719 - acc: 1.0000
# Epoch 77/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.1698 - acc: 1.0000
# Epoch 78/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1678 - acc: 1.0000
# Epoch 79/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.1658 - acc: 1.0000
# Epoch 80/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1639 - acc: 1.0000
# Epoch 81/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1619 - acc: 1.0000
# Epoch 82/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.1601 - acc: 1.0000
# Epoch 83/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1582 - acc: 1.0000
# Epoch 84/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1564 - acc: 1.0000
# Epoch 85/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1546 - acc: 1.0000
# Epoch 86/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1529 - acc: 1.0000
# Epoch 87/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1511 - acc: 1.0000
# Epoch 88/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.1495 - acc: 1.0000
# Epoch 89/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1478 - acc: 1.0000
# Epoch 90/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1462 - acc: 1.0000
# Epoch 91/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1446 - acc: 1.0000
# Epoch 92/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1430 - acc: 1.0000
# Epoch 93/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1415 - acc: 1.0000
# Epoch 94/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1400 - acc: 1.0000
# Epoch 95/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.1385 - acc: 1.0000
# Epoch 96/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1370 - acc: 1.0000
# Epoch 97/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1356 - acc: 1.0000
# Epoch 98/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.1341 - acc: 1.0000
# Epoch 99/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1327 - acc: 1.0000
# Epoch 100/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1314 - acc: 1.0000

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
model.predict(X)
# Out:
# array([[0.00638998],
#        [0.14747661],
#        [0.1477516 ],
#        [0.82342684]], dtype=float32)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
model.layers[0].get_weights()
# Out:
# [array([[3.2942703],
#         [3.2920847]], dtype=float32), array([-5.0466156], dtype=float32)]

# %%
pred = model.predict(X)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
pred
# Out:
# array([[0.00638998],
#        [0.14747661],
#        [0.1477516 ],
#        [0.82342684]], dtype=float32)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
pred
# Out:
# array([[0.00638998],
#        [0.14747661],
#        [0.1477516 ],
#        [0.82342684]], dtype=float32)

# %%
np.where(pred >= 0.5 , 1 , 0)
# Out:
# array([[0],
#        [0],
#        [0],
#        [1]])
